# %% [markdown]
# <a href="https://colab.research.google.com/github/Christine-Miller/Christine-Miller/blob/main/2025_simulations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Run these cells

# %%
# !pip install datascience

# %%
import numpy as np
from datascience import *
import random

# %% [markdown]
# # Simulations
#
# Today we will work on code to simulate one or more of the scenarios described below. We need to use steps 1 through 4 to structure your work. We'll do the first one together and then you will try the two remaining for HW.

# %% [markdown]
# ## Option 1: icecream
#
# Orders of frozen yogurt flavors have the following relative frequencies based on sales: 38% chocolate, 42% vanilla, and 20% strawberry. Three students enter the yogurt store and order a yogurt. Assuming each order is independent of the other and no yogurt runs out, what is the probability that each student orders a different flavor? Give an empirical estimate using a simulation model.

# %% [markdown]
# 1. State the problem and assumptions here:
#
# In the code cell below:
# 2. Design one trial in code
#
# 3. Code the simulation for 10,000 trials
#
# 4. State your conclusions based on your simulation

# %% [markdown]
# ## Option 2: ageism
#
# A gentleman sent the following letter to the ombudsman at his local newspaper. “The company I worked for recently laid off 10 of its sales staff, including me, due to budget cuts. After talking to one of my former fellow workers, we realized that 6 out of 10 people they fired were over 55—while a large proportion of the younger sales staff---who are paid less—kept their jobs. Assume the company has over 200 employees and that 24% of all sales people in the last census were 55 years or older. How can I find out if I have an age discrimination case and where can I turn for help?

# %% [markdown]
# 1. State the problem and assumptions here:
#
# In the code cell below:
#
# 2. Design one trial in code
#
# 3. Code the simulation for 10,000 trials
#
# 4. State your conclusions based on your simulation

# %% [markdown]
# #3: Cheerios Prizes

# %% [markdown]
# Cheerios boxes displayed a dollar bill on the front of the box and a cartoon that said, "Free dollar bill in every 20th box." I had to buy 50 boxes before I got my first one dollar.
# Design a simulation that estimates the probability of getting 49 boxes without a dollar bill and then $1 in the 50th box.

# %% [markdown]
# 1. State the problem and assumptions here:
#
# In the code cell below:
#
# 2. Design one trial in code
#
# 3. Code the simulation for 10,000 trials
#
# 4. State your conclusions based on your simulation
